# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ### Assumptions
# - women, children and elderly survive
# - rich probably survive - Pclass 1 & 2
#     - higher chances of survival if rich and woman/child
# - families stay together

# %% [markdown]
# ## Problem - what sorts of people were more likely to survive?

# %%
#load datasets
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.columns, test.columns
# Out:
# (Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object'),
#  Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#         'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object'))

# %%
def age_bar(x):
    if x<=10:
        return 'child'
    elif x>10 and x<=20:
        return 'adolescent'
    elif x>20 and x<=30:
        return 'young'
    elif x>30 and x<=40:
        return 'mature'
    elif x>40 and x<=50:
        return ''

# %%
train['Age_floor'] = train.Age.apply(lambda x: x if (math.isnan(x)) else int(math.floor(x)))

# %%
train['Surname'] = train.Name.apply(lambda x: x.split(',')[0])

# %%
train['Title'] = train.Name.apply(lambda x: x.split(',')[1].split('.')[0])

# %%
train[train.Fare == max(train.Fare)]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      Age_floor  Surname  Title
# 258       35.0     Ward   Miss
# 679       36.0  Cardeza     Mr
# 737       35.0  Lesurer     Mr

# %% [markdown]
# - Avg Fare for PClass 1 = 84.154687
#     - above this: survived - 51, died - 15
#     - below this: survived - 291, died - 534
# - Avg Fare for PClass 2 = 20.662183
#     - above this: survived - 195, died - 172
#     - below this: survived - 147, died - 377
# - Avg Fare for PClass 3 = 13.675550
#     - above this: survived - 234, died - 224
#     - below this: survived - 108, died - 325

# %%
train[train.Pclass == 3].Fare.describe()
# Out:
# count    491.000000
# mean      13.675550
# std       11.778142
# min        0.000000
# 25%        7.750000
# 50%        8.050000
# 75%       15.500000
# max       69.550000
# Name: Fare, dtype: float64

# %%
train[train.Fare<=20.662183 ].Survived.value_counts()
# Out:
# 0    377
# 1    147
# Name: Survived, dtype: int64

# %%
# are you more likely to survive alone or in a family?
train.groupby(['Surname'])['Survived'].agg(['sum','count'])
# Out:
#                sum  count
# Surname
# Abbing           0      1
# Abbott           1      2
# Abelson          1      2
# Adahl            0      1
# Adams            0      1
# ...            ...    ...
# de Mulder        1      1
# de Pelsmaeker    0      1
# del Carlo        0      1
# van Billiard     0      1
# van Melkebeke    0      1
#
# [667 rows x 2 columns]

# %%
train[train['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked  Age_floor   Surname  \
# 1        0  PC 17599  71.2833          C85        C       38.0   Cumings
# 3        0    113803  53.1000         C123        S       35.0  Futrelle
# 6        0     17463  51.8625          E46        S       54.0  McCarthy
# 11       0    113783  26.5500         C103        S       58.0   Bonnell
# 23       0    113788  35.5000           A6        S       28.0    Sloper
# ..     ...       ...      ...          ...      ...        ...       ...
# 871      1     11751  52.5542          D35        S       47.0  Beckwith
# 872      0       695   5.0000  B51 B53 B55        S       33.0  Carlsson
# 879      1     11767  83.1583          C50        C       56.0    Potter
# 887      0    112053  30.0000          B42        S       19.0    Graham
# 889      0    111369  30.0000         C148        C       26.0      Behr
#
#      Title
# 1      Mrs
# 3      Mrs
# 6       Mr
# 11    Miss
# 23      Mr
# ..     ...
# 871    Mrs
# 872     Mr
# 879    Mrs
# 887   Miss
# 889     Mr
#
# [216 rows x 15 columns]

# %%
train[(train.Sex=='female') & (train.Age_floor<=10) & (train.Survived ==1)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 58            59         1       2              West, Miss. Constance Mirium
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 184          185         1       3       Kink-Heilmann, Miss. Luise Gretchen
# 233          234         1       3            Asplund, Miss. Lillian Gertrud
# 237          238         1       2          Collyer, Miss. Marjorie "Lottie"
# 381          382         1       3               Nakid, Miss. Maria ("Mary")
# 448          449         1       3            Baclini, Miss. Marie Catherine
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 479          480         1       3                  Hirvonen, Miss. Hildur E
# 530          531         1       2                  Quick, Miss. Phyllis May
# 535          536         1       2                    Hart, Miss. Eva Miriam
# 618          619         1       2               Becker, Miss. Marion Louise
# 644          645         1       3                    Baclini, Miss. Eugenie
# 691          692         1       3                        Karun, Miss. Manca
# 720          721         1       2         Harper, Miss. Annie Jessie "Nina"
# 750          751         1       2                         Wells, Miss. Joan
# 777          778         1       3             Emanuel, Miss. Virginia Ethel
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked  \
# 10   female  4.00      1      1        PP 9549  16.7000    G6        S
# 43   female  3.00      1      2  SC/Paris 2123  41.5792   NaN        C
# 58   female  5.00      1      2     C.A. 34651  27.7500   NaN        S
# 172  female  1.00      1      1         347742  11.1333   NaN        S
# 184  female  4.00      0      2         315153  22.0250   NaN        S
# 233  female  5.00      4      2         347077  31.3875   NaN        S
# 237  female  8.00      0      2     C.A. 31921  26.2500   NaN        S
# 381  female  1.00      0      2           2653  15.7417   NaN        C
# 448  female  5.00      2      1           2666  19.2583   NaN        C
# 469  female  0.75      2      1           2666  19.2583   NaN        C
# 479  female  2.00      0      1        3101298  12.2875   NaN        S
# 530  female  2.00      1      1          26360  26.0000   NaN        S
# 535  female  7.00      0      2   F.C.C. 13529  26.2500   NaN        S
# 618  female  4.00      2      1         230136  39.0000    F4        S
# 644  female  0.75      2      1           2666  19.2583   NaN        C
# 691  female  4.00      0      1         349256  13.4167   NaN        C
# 720  female  6.00      0      1         248727  33.0000   NaN        S
# 750  female  4.00      1      1          29103  23.0000   NaN        S
# 777  female  5.00      0      0         364516  12.4750   NaN        S
#
#      Age_floor        Surname  Title
# 10         4.0      Sandstrom   Miss
# 43         3.0        Laroche   Miss
# 58         5.0           West   Miss
# 172        1.0        Johnson   Miss
# 184        4.0  Kink-Heilmann   Miss
# 233        5.0        Asplund   Miss
# 237        8.0        Collyer   Miss
# 381        1.0          Nakid   Miss
# 448        5.0        Baclini   Miss
# 469        0.0        Baclini   Miss
# 479        2.0       Hirvonen   Miss
# 530        2.0          Quick   Miss
# 535        7.0           Hart   Miss
# 618        4.0         Becker   Miss
# 644        0.0        Baclini   Miss
# 691        4.0          Karun   Miss
# 720        6.0         Harper   Miss
# 750        4.0          Wells   Miss
# 777        5.0        Emanuel   Miss

# %%
train[train.Surname=='Asplund']
# Out:
#      PassengerId  Survived  Pclass  \
# 25            26         1       3
# 182          183         0       3
# 233          234         1       3
# 261          262         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 182              Asplund, Master. Clarence Gustaf Hugo    male   9.0      4
# 233                     Asplund, Miss. Lillian Gertrud  female   5.0      4
# 261                  Asplund, Master. Edvin Rojj Felix    male   3.0      4
#
#      Parch  Ticket     Fare Cabin Embarked  Age_floor  Surname    Title
# 25       5  347077  31.3875   NaN        S       38.0  Asplund      Mrs
# 182      2  347077  31.3875   NaN        S        9.0  Asplund   Master
# 233      2  347077  31.3875   NaN        S        5.0  Asplund     Miss
# 261      2  347077  31.3875   NaN        S        3.0  Asplund   Master

# %%
test[test.Name.str.contains('Asplund')]
# Out:
#      PassengerId  Pclass                                        Name   Sex  \
# 154         1046       3                Asplund, Master. Filip Oscar  male
# 174         1066       3  Asplund, Mr. Carl Oscar Vilhelm Gustafsson  male
# 226         1118       3                  Asplund, Mr. Johan Charles  male
# 379         1271       3                 Asplund, Master. Carl Edgar  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 154  13.0      4      2  347077  31.3875   NaN        S
# 174  40.0      1      5  347077  31.3875   NaN        S
# 226  23.0      0      0  350054   7.7958   NaN        S
# 379   5.0      4      2  347077  31.3875   NaN        S

# %%
train.groupby(['Title']).mean()['Age']
# Out:
# Title
#  Capt            70.000000
#  Col             58.000000
#  Don             40.000000
#  Dr              42.000000
#  Jonkheer        38.000000
#  Lady            48.000000
#  Major           48.500000
#  Master           4.574167
#  Miss            21.773973
#  Mlle            24.000000
#  Mme             24.000000
#  Mr              32.368090
#  Mrs             35.898148
#  Ms              28.000000
#  Rev             43.166667
#  Sir             49.000000
#  the Countess    33.000000
# Name: Age, dtype: float64

# %%
train.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train.groupby(['Age']).sum('Survived').reset_index()[['Survived', 'Age']]
# Out:
#     Survived    Age
# 0          1   0.42
# 1          1   0.67
# 2          2   0.75
# 3          2   0.83
# 4          1   0.92
# ..       ...    ...
# 83         0  70.00
# 84         0  70.50
# 85         0  71.00
# 86         0  74.00
# 87         1  80.00
#
# [88 rows x 2 columns]

# %%
train.groupby(['Pclass']).sum('Survived').reset_index()[['Survived', 'Pclass']]
# Out:
#    Survived  Pclass
# 0       136       1
# 1        87       2
# 2       119       3

# %%
train.groupby(['Sex']).sum('Survived').reset_index()[['Survived', 'Sex']]
# Out:
#    Survived     Sex
# 0       233  female
# 1       109    male

# %%
train[train.Age>75]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked  Age_floor  \
# 630  male  80.0      0      0  27042  30.0   A23        S       80.0
#
#        Surname Title
# 630  Barkworth    Mr

# %%
train[train.Name.str.contains('Braund')]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 0              1         0       3    Braund, Mr. Owen Harris  male  22.0
# 477          478         0       3  Braund, Mr. Lewis Richard  male  29.0
#
#      SibSp  Parch     Ticket    Fare Cabin Embarked  Age_floor Surname Title
# 0        1      0  A/5 21171  7.2500   NaN        S       22.0  Braund    Mr
# 477      1      0       3460  7.0458   NaN        S       29.0  Braund    Mr

# %%
train[train.Name.str.contains('Cumings')]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked  Age_floor  Surname Title
# 1      0  PC 17599  71.2833   C85        C       38.0  Cumings   Mrs

# %% [markdown]
# ## Example

# %%
gender_submission = pd.read_csv('gender_submission.csv')

# %%
gender_submission.Survived.value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
gender_submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
